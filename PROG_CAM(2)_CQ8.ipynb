# %% [markdown]
# <a href="https://colab.research.google.com/github/aduran162/PROGCOM-A/blob/main/PROG_CAM(2)_CQ8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# REPOSITORIO DE ERRORES EN PYTHON Y JAVA
# 40 en Python + 40 en Java

# ERRORES EN PYTHON (40 ejemplos)

# 1. KeyError
# Acceder a una clave inexistente en un diccionario.
data = {"USA":1, "China":2}
# print(data["Japan"])   # Error: KeyError: 'Japan'
print(data.get("Japan", "No encontrado"))  # Solución

# 2. IndexError
nums = [1,2,3]
# print(nums[5])  # Error: IndexError
print(nums[-1])   # Solución

# 3. ZeroDivisionError
# x = 5/0  # Error: ZeroDivisionError
x = 5/1    # Solución

# 4. NameError
# print(valor)  # Error: NameError
valor = 10
print(valor)  # Solución

# 5. TypeError
# "5" + 2  # Error: TypeError
print(int("5") + 2)  # Solución

# 6. AttributeError
# x = 5; x.append(10)  # Error: AttributeError
lista = [5]; lista.append(10)  # Solución

# 7. IndentationError
def f():
    print("hola")  # Solución

# 8. SyntaxError
# if True print("Hola")  # Error: SyntaxError
if True: print("Hola")  # Solución

# 9. ValueError
# int("abc")  # Error: ValueError
print(int("123"))  # Solución

# 10. ImportError
# import noexiste  # Error: ImportError
import math  # Solución

# 11. OverflowError
import math
try:
    # math.exp(1000)  # Error: OverflowError
    math.exp(10)     # Solución
except OverflowError:
    print("Número demasiado grande")

# 12. FileNotFoundError
try:
    # open("noexiste.txt")  # Error: FileNotFoundError
    open("archivo.txt","w") # Solución
except: pass

# 13. IsADirectoryError
try:
    # open("/")  # Error: IsADirectoryError
    open("archivo.txt","w")  # Solución
except: pass

# 14. PermissionError
try:
    # open("/root/archivo.txt","w")  # Error: PermissionError
    open("archivo.txt","w")         # Solución
except: pass

# 15. MemoryError
try:
    # x = [1]*100000000000  # Error: MemoryError
    x = [1]*1000            # Solución
except: pass

# 16. UnicodeDecodeError
try:
    # open("archivo.txt", encoding="ascii").read()  # Error si hay acentos
    open("archivo.txt", encoding="utf8")          # Solución
except: pass

# 17. RecursionError
import sys
sys.setrecursionlimit(50)
def rec(): return rec()
try:
    # rec()  # Error: RecursionError
    pass
except: pass

# 18. AssertionError
# assert 2+2==5  # Error: AssertionError
assert 2+2==4    # Solución

# 19. StopIteration
def gen():
    yield 1
g = gen()
next(g)
# next(g)  # Error: StopIteration

# 20. KeyboardInterrupt
# Ocurre al parar con Ctrl+C en consola.

# 21. ModuleNotFoundError
# import inexistente  # Error
import math          # Solución

# 22. RuntimeError
import threading
lock = threading.Lock()
try:
    # lock.release()  # Error: RuntimeError
    pass
except: pass

# 23. FloatingPointError
import numpy as np
np.seterr(all="raise")
try:
    # np.divide(1.0,0.0)  # Error: FloatingPointError
    np.divide(1.0,1.0)   # Solución
except: pass

# 24. ArithmeticError
try:
    # 1/0  # Error
    1/1   # Solución
except: pass

# 25. EOFError
# input()  # Error si no hay entrada

# 26. OSError
import os
try:
    # os.remove("noexiste.txt")  # Error
    pass
except: pass

# 27. TimeoutError
import socket
try:
    s=socket.socket()
    s.settimeout(0.001)
    # s.connect(("10.255.255.1",80))  # Error: TimeoutError
except: pass

# 28. BrokenPipeError
import subprocess
try:
    p = subprocess.Popen(["echo"],stdout=subprocess.PIPE)
    p.stdout.close()
    # p.wait()  # podría dar BrokenPipeError
except: pass

# 29. ConnectionError
# requests.get("http://127.0.0.1:9999")  Error

# 30. NotImplementedError
def f():
    raise NotImplementedError("Falta implementar")
# f()  Error

# 31. DeprecationWarning
import warnings
warnings.warn("Función antigua", DeprecationWarning)

# 32. FutureWarning
warnings.warn("Uso futuro", FutureWarning)

# 33. UserWarning
warnings.warn("Esto es solo aviso", UserWarning)

# 34. SystemExit
# exit()  termina ejecución

# 35. ImportWarning
warnings.warn("Import no usado", ImportWarning)

# 36. SyntaxWarning
warnings.warn("Posible error de sintaxis", SyntaxWarning)

# 37. UnicodeWarning
warnings.warn("Problema unicode", UnicodeWarning)

# 38. BytesWarning
warnings.warn("Problema bytes", BytesWarning)

# 39. ResourceWarning
warnings.warn("Recurso abierto", ResourceWarning)

# 40. KeyboardInterrupt
# Ya explicado.


# ERRORES EN JAVA (40 ejemplos, solo texto)

"""
1. NullPointerException
   Error: cuando un objeto es null y se intenta usar.
   Solución: verificar si es null antes de usar.

2. ArrayIndexOutOfBoundsException
   Error: acceder fuera de rango de un arreglo.
   Solución: usar índices válidos.

3. ArithmeticException
   Error: división entre 0.
   Solución: validar divisor.

4. NumberFormatException
   Error: Integer.parseInt("abc")
   Solución: Integer.parseInt("123")

5. ClassNotFoundException
   Error: Class.forName("NoExiste")
   Solución: usar clase existente.

6. FileNotFoundException
   Error: new FileReader("no.txt")
   Solución: validar existencia.

7. IOException
   Error: al leer/escribir archivo.
   Solución: manejar con trycatch.

8. SQLException
   Error: conexión o consulta fallida.
   Solución: revisar conexión.

9. IllegalArgumentException
   Error: argumento inválido.
   Solución: validar antes.

10. IllegalStateException
    Error: objeto en estado incorrecto.
    Solución: asegurar estado válido.

11. ConcurrentModificationException
    Error: modificar lista mientras se itera.
    Solución: usar Iterator.remove()

12. UnsupportedOperationException
    Error: método no soportado.
    Solución: usar métodos válidos.

13. ClassCastException
    Error: cast inválido.
    Solución: comprobar instancia.

14. AssertionError
    Error: assert false.
    Solución: assert true.

15. StackOverflowError
    Error: recursión infinita.
    Solución: asegurar caso base.

16. OutOfMemoryError
    Error: demasiados objetos.
    Solución: liberar memoria.

17. NoSuchMethodException
    Error: método inexistente con reflexión.
    Solución: usar método real.

18. InstantiationException
    Error: instanciar clase abstracta.
    Solución: instanciar concreta.

19. IllegalAccessException
    Error: acceso a campo privado.
    Solución: usar acceso válido.

20. NoSuchFieldException
    Error: campo inexistente.
    Solución: usar campo válido.

21. InterruptedException
    Error: hilo interrumpido.
    Solución: manejar interrupción.

22. TimeoutException
    Error: espera excedida.
    Solución: configurar tiempos.

23. SecurityException
    Error: violación de seguridad.
    Solución: permisos correctos.

24. MissingResourceException
    Error: recurso no encontrado.
    Solución: verificar ruta.

25. DuplicateFormatFlagsException
    Error: String.format con flags duplicadas.
    Solución: revisar flags.

26. FormatterClosedException
    Error: usar formatter cerrado.
    Solución: usar abierto.

27. InputMismatchException
    Error: Scanner.nextInt() con letras.
    Solución: validar entrada.

28. IllegalFormatException
    Error: formato de string inválido.
    Solución: revisar formato.

29. PatternSyntaxException
    Error: regex inválida.
    Solución: corregir expresión.

30. ProviderNotFoundException
    Error: servicio ausente.
    Solución: añadir dependencia.

31. UncheckedIOException
    Error: IO error envuelto.
    Solución: manejar IO.

32. DateTimeParseException
    Error: parseo fecha inválido.
    Solución: usar formato correcto.

33. NegativeArraySizeException
    Error: new int[-5]
    Solución: tamaño positivo.

34. IllegalMonitorStateException
    Error: notify() sin sincronizar.
    Solución: usar synchronized.

35. MissingFormatArgumentException
    Error: String.format("%s %s","Hola")
    Solución: pasar todos los argumentos.

36. UnknownFormatConversionException
    Error: String.format("%q","x")
    Solución: usar conversión válida.

37. EmptyStackException
    Error: pop() en pila vacía.
    Solución: validar antes.

38. ConcurrentModificationException
    Error: modificación concurrente.
    Solución: usar colecciones seguras.

39. RejectedExecutionException
    Error: Executor saturado.
    Solución: ajustar pool.

40. IllegalThreadStateException
    Error: hilo ya iniciado.
    Solución: crear nuevo hilo.
"""
